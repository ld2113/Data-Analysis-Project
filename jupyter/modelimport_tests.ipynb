# %%
import os
os.environ["THEANO_FLAGS"] = "device=cuda1"

from __future__ import print_function
from __future__ import division
from __future__ import absolute_import

import numpy as np
import pandas as pd
import sys
import pickle
import copy
import time

import sklearn.metrics as met

from keras import regularizers
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Dropout, Activation, Embedding, Flatten, BatchNormalization
# Out:
# Using Theano backend.
# Using cuDNN version 5110 on context None
# Mapped name None to device cuda1: Tesla K80 (0000:05:00.0)

# %%
model = load_model('../dummy_model.hdf5')

data = np.load('../arrays/prediction/predictnames_inter55m_emb.npy')

#model.save_weights('../dummy_weights.hdf5')
#del model

# %%
prediction = model.predict([data,data,data], batch_size=64, verbose=1)

# %%
np.array(model.layers[5].get_config())
# Out:
# array({'name': 'embedding_3', 'trainable': False, 'batch_input_shape': (None, 2), 'dtype': 'int32', 'input_dim': 16109, 'output_dim': 512, 'embeddings_initializer': {'class_name': 'RandomUniform', 'config': {'minval': -0.05, 'maxval': 0.05, 'seed': None}}, 'embeddings_regularizer': None, 'activity_regularizer': None, 'embeddings_constraint': None, 'mask_zero': False, 'input_length': 2}, dtype=object)

# %%
np.array(model.layers[0].get_weights())
# Out:
# array([], dtype=float64)

# %%
np.load('../arrays/encoded_go_tanh_512.npy')
# Out:
# array([[-0.32699332, -0.48521036,  0.8996498 , ..., -0.99550581,
#         -0.99963379, -0.14571865],
#        [ 0.55617934, -0.11030591,  0.61888957, ..., -0.55846298,
#          0.17611077,  0.49546489],
#        [ 0.81478667, -0.94073701,  0.41935906, ..., -0.04942205,
#         -0.81456131,  0.93552583],
#        ...,
#        [ 0.55617934, -0.11030591,  0.61888957, ..., -0.55846298,
#          0.17611077,  0.49546489],
#        [ 0.55617934, -0.11030591,  0.61888957, ..., -0.55846298,
#          0.17611077,  0.49546489],
#        [ 0.55617934, -0.11030591,  0.61888957, ..., -0.55846298,
#          0.17611077,  0.49546489]], dtype=float32)

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# coord_in (InputLayer)            (None, 2)             0
# ____________________________________________________________________________________________________
# dom_in (InputLayer)              (None, 2)             0
# ____________________________________________________________________________________________________
# go_in (InputLayer)               (None, 2)             0
# ____________________________________________________________________________________________________
# embedding_1 (Embedding)          (None, 2, 4)          64436
# ____________________________________________________________________________________________________
# embedding_2 (Embedding)          (None, 2, 512)        8247808
# ...
